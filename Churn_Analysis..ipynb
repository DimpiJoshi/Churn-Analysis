# %%
#import the required libraries

import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.ticker as mtick

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Customer-Churn.csv')

#Excel: pd.read_excel
#Text: pd.read_csv sep: ' ' ','';'':'

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
#checking the data types of all the columns
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#check the descriptive statistics of numeric variables
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts()/len(df)*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
df['Churn'].value_counts().plot(kind='barh')
#plt.xlabel('Count')
#plt.ylabel('Target Variable')
#plt.title("Count of TARGET variable per category")
# Out:
# <Axes: >

# %%
df['Churn'].value_counts().plot(kind='barh',figsize = (4,4))
plt.xlabel("Count")
plt.ylabel("Target Variable")
plt.title("Count of TARGET variable per category")
# Out:
# Text(0.5, 1.0, 'Count of TARGET variable per category')

# %%
df['Churn'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# *   Data is highly imbalanced, ratio = 73:27
# *   So we analyse the data with other features while taking the target values separately to get some insights.

# %%
# Consice summery of the dataframe, as we have too many columns, we are using the verbase = true mode
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
missing = pd.DataFrame((df.isnull().sum()) * 100 / df.shape[0]).reset_index()

missing.columns = ['column', 'missing_percentage']

plt.figure(figsize=(16, 5))

ax = sns.pointplot(x='column', y='missing_percentage', data=missing)

plt.xticks(rotation=90, fontsize=7)

plt.title("Percentage of Missing Values")

plt.ylabel("PERCENTAGE")

plt.show()

# %%
missing
# Out:
#               column  missing_percentage
# 0         customerID                 0.0
# 1             gender                 0.0
# 2      SeniorCitizen                 0.0
# 3            Partner                 0.0
# 4         Dependents                 0.0
# 5             tenure                 0.0
# 6       PhoneService                 0.0
# 7      MultipleLines                 0.0
# 8    InternetService                 0.0
# 9     OnlineSecurity                 0.0
# 10      OnlineBackup                 0.0
# 11  DeviceProtection                 0.0
# 12       TechSupport                 0.0
# 13       StreamingTV                 0.0
# 14   StreamingMovies                 0.0
# 15          Contract                 0.0
# 16  PaperlessBilling                 0.0
# 17     PaymentMethod                 0.0
# 18    MonthlyCharges                 0.0
# 19      TotalCharges                 0.0
# 20             Churn                 0.0

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# 1. Create a copy of base data for manupulation & processing

# %%
new_df = df.copy()

# %% [markdown]
# 2.  Total charges should be numeric amount. Let's convert it to numerical data type

# %%
new_df.TotalCharges = pd.to_numeric(new_df.TotalCharges, errors= 'coerce')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
new_df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
missing = pd.DataFrame((new_df.isnull().sum()) * 100 / new_df.shape[0]).reset_index()

missing.columns = ['column', 'missing_percentage']

plt.figure(figsize=(16, 5))

ax = sns.pointplot(x='column', y='missing_percentage', data=missing)

plt.xticks(rotation=90, fontsize=7)

plt.title("Percentage of Missing Values")

plt.ylabel("PERCENTAGE")

plt.show()

# %% [markdown]
# 3. As we can see there are 11 missing values in Totalcharges column. Let's check these records.

# %%
new_df.loc[new_df ['TotalCharges'].isnull() == True]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# 4.  Missing values Treatment
#
# Since the % of these records compared to total dataset is very low ie 0.15%, it is safe to ignore them from further processing.

# %%
# Removing missing values
new_df.dropna(how ='any', inplace = True)
#new_df.fillna(0)

# %%
new_df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
new_df.shape
# Out:
# (7032, 21)

# %% [markdown]
# 5. Divide customers into bins based on tenure e.g. months<12 months

# %%
# Get the max tenure

print(new_df['tenure'].max()) #72
# Out:
# 72

# %%
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]
print(labels)
# Out:
# ['1 - 12', '13 - 24', '25 - 36', '37 - 48', '49 - 60', '61 - 72']

# %%
# Group the tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]
new_df['tenure_group'] = pd.cut(new_df.tenure, range(1, 80, 12), right=False, labels=labels)

# %%
new_df['tenure_group'].value_counts()
# Out:
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: tenure_group, dtype: int64

# %% [markdown]
# 6. Remove columns not required for processing

# %%
#drop column customerID and tenure

new_df.drop(columns= ['customerID','tenure'], axis=1, inplace=True)

# %%
new_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ## Univariate Analysis

# %%
new_df.head(5)
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
new_df['Churn'].value_counts()/len(df)*100
# Out:
# No     73.306829
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
for i, predictor in enumerate(new_df.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges'])):

    plt.figure(i)

    sns.countplot(data=new_df, x=predictor, hue='Churn')

# %%
new_df.gender.value_counts()
# Out:
# Male      3549
# Female    3483
# Name: gender, dtype: int64

# %%
new_df1_target0=new_df[new_df["Churn"]=='No']
new_df1_target1=new_df[new_df["Churn"]=='Yes']

# %%
new_df1_target1.gender.value_counts()
# Out:
# Female    939
# Male      930
# Name: gender, dtype: int64

# %%
new_df.SeniorCitizen.value_counts()
# Out:
# 0    5890
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
new_df1_target1.SeniorCitizen.value_counts()
# Out:
# 0    1393
# 1     476
# Name: SeniorCitizen, dtype: int64

# %%
new_df.Partner.value_counts()
# Out:
# No     3639
# Yes    3393
# Name: Partner, dtype: int64

# %%
new_df1_target1.Partner.value_counts()
# Out:
# No     1200
# Yes     669
# Name: Partner, dtype: int64

# %%
new_df.Dependents.value_counts()
# Out:
# No     4933
# Yes    2099
# Name: Dependents, dtype: int64

# %%
new_df1_target1.Dependents.value_counts()
# Out:
# No     1543
# Yes     326
# Name: Dependents, dtype: int64

# %%
new_df.PhoneService.value_counts()
# Out:
# Yes    6352
# No      680
# Name: PhoneService, dtype: int64

# %%
new_df1_target1.PhoneService.value_counts()
# Out:
# Yes    1699
# No      170
# Name: PhoneService, dtype: int64

# %%
new_df.MultipleLines.value_counts()
# Out:
# No                  3385
# Yes                 2967
# No phone service     680
# Name: MultipleLines, dtype: int64

# %%
new_df1_target1.MultipleLines.value_counts()
# Out:
# Yes                 850
# No                  849
# No phone service    170
# Name: MultipleLines, dtype: int64

# %%
new_df.InternetService.value_counts()
# Out:
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: InternetService, dtype: int64

# %%
new_df1_target1.InternetService.value_counts()
# Out:
# Fiber optic    1297
# DSL             459
# No              113
# Name: InternetService, dtype: int64

# %%
new_df.OnlineSecurity.value_counts()
# Out:
# No                     3497
# Yes                    2015
# No internet service    1520
# Name: OnlineSecurity, dtype: int64

# %%
new_df1_target1.OnlineSecurity.value_counts()
# Out:
# No                     1461
# Yes                     295
# No internet service     113
# Name: OnlineSecurity, dtype: int64

# %%
new_df.OnlineBackup.value_counts()
# Out:
# No                     3087
# Yes                    2425
# No internet service    1520
# Name: OnlineBackup, dtype: int64

# %%
new_df1_target1.OnlineBackup.value_counts()
# Out:
# No                     1233
# Yes                     523
# No internet service     113
# Name: OnlineBackup, dtype: int64

# %%
new_df.DeviceProtection.value_counts()
# Out:
# No                     3094
# Yes                    2418
# No internet service    1520
# Name: DeviceProtection, dtype: int64

# %%
new_df1_target1.DeviceProtection.value_counts()
# Out:
# No                     1211
# Yes                     545
# No internet service     113
# Name: DeviceProtection, dtype: int64

# %%
new_df.TechSupport.value_counts()
# Out:
# No                     3472
# Yes                    2040
# No internet service    1520
# Name: TechSupport, dtype: int64

# %%
new_df1_target1.TechSupport.value_counts()
# Out:
# No                     1446
# Yes                     310
# No internet service     113
# Name: TechSupport, dtype: int64

# %%
new_df.StreamingTV.value_counts()
# Out:
# No                     2809
# Yes                    2703
# No internet service    1520
# Name: StreamingTV, dtype: int64

# %%
new_df1_target1.StreamingTV.value_counts()
# Out:
# No                     942
# Yes                    814
# No internet service    113
# Name: StreamingTV, dtype: int64

# %%
new_df.StreamingMovies.value_counts()
# Out:
# No                     2781
# Yes                    2731
# No internet service    1520
# Name: StreamingMovies, dtype: int64

# %%
new_df1_target1.StreamingMovies.value_counts()
# Out:
# No                     938
# Yes                    818
# No internet service    113
# Name: StreamingMovies, dtype: int64

# %%
new_df.Contract.value_counts()
# Out:
# Month-to-month    3875
# Two year          1685
# One year          1472
# Name: Contract, dtype: int64

# %%
new_df1_target1.Contract.value_counts()
# Out:
# Month-to-month    1655
# One year           166
# Two year            48
# Name: Contract, dtype: int64

# %%
new_df.PaperlessBilling.value_counts()
# Out:
# Yes    4168
# No     2864
# Name: PaperlessBilling, dtype: int64

# %%
new_df1_target1.PaperlessBilling.value_counts()
# Out:
# Yes    1400
# No      469
# Name: PaperlessBilling, dtype: int64

# %%
new_df.PaymentMethod.value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: PaymentMethod, dtype: int64

# %%
new_df1_target1.PaymentMethod.value_counts()
# Out:
# Electronic check             1071
# Mailed check                  308
# Bank transfer (automatic)     258
# Credit card (automatic)       232
# Name: PaymentMethod, dtype: int64

# %%
new_df.tenure_group.value_counts()
# Out:
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: tenure_group, dtype: int64

# %%
new_df1_target1.tenure_group.value_counts()
# Out:
# 1 - 12     1037
# 13 - 24     294
# 25 - 36     180
# 37 - 48     145
# 49 - 60     120
# 61 - 72      93
# Name: tenure_group, dtype: int64

# %% [markdown]
# ## Univariate Insights
#
# *   Graph1-Gender: Males and Females are equally likely to churn.
# *   Graph2-SeniorCitizen: Seniorcitizens are most likely to churn, around 42% churn rate
# *   Graph3-Partner: people who don't have partner are likely to churn, around 33% churn rate
# *   Graph4-Dependents: Depenedents are most likely to churn, around 31% churn rate
# *   Graph5-PhoneService: People who have phoneservice and who don't have phoneservice are equally like to churn.
# *   Graph6-Multiple lines: Churn rate is almost same for all multiple lines users.
# *   Graph7-InternetService: People who have fiberoptic are most likely to churn, around 42% churn rate
# *   Graph8-Online Security: People who don't have online security are most likely to churn, around 42% churn rate
# *   Graph9-Online Backup: Who don't have online backup are most likely to churn, around 40% churn rate
# *   Graph10-Device protection: People who don't have Device protection are most likely to churn, around 39% churn rate
# *   Graph11-Tech support: People who don't have techsupport are likely to churn, around 42% churn rate
# *   Graph12/13-Streaming TV/Movies: Equally churn around 32% churn rate
# *   Graph14-Contract: People who have monthly contract are most likely to churn, around 42% churn rate. 2 Year contract people are leass like to churn.
# *   Graph15-Paperless billing: Paperless billing customers are like to churn, around 34% churn rate
# *   Graph16-Payment method: People who have Electronic check Payment method are most like to churn, around 44% churn rate
# *   Graph17-tenure_group: tenure group (1 -12 months) are most like to churn,around 48% churn rate

# %%
pd.crosstab(new_df.PaymentMethod, new_df.Churn)
# Out:
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1284   258
# Credit card (automatic)    1289   232
# Electronic check           1294  1071
# Mailed check               1296   308

# %% [markdown]
# 2. Convert the target variable 'Churn' in a binary numeric variaqble i.e. Yes=1: No=0

# %%
new_df.head(5)
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
new_df['Churn'] = np.where(new_df.Churn =='Yes',1,0)

# %%
new_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
# For Machine Learning (predictive Modeling), we need to perform Feature Encoding
new_df_dummies = pd.get_dummies(new_df)
new_df_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %% [markdown]
# 9. Relationship betaween MonthlyCharges and TotalCharges

# %%
sns.lmplot(data=new_df, x='MonthlyCharges', y = 'TotalCharges', fit_reg= False)

# %%
new_df['MonthlyCharges'].corr(new_df['TotalCharges'])
# Out:
# 0.6510648032262027

# %% [markdown]
# Total Charges increase as Monthly Charges increase - as expected.

# %% [markdown]
# *   Churn by Monthly Charges and Total Charges

# %%
Mth = sns.kdeplot(new_df.MonthlyCharges[(new_df["Churn"] == 0)],
                  color='Red', fill = True)
Mth = sns.kdeplot(new_df.MonthlyCharges[(new_df["Churn"] == 1)],
                ax = Mth, color= 'Blue', fill = True )
Mth.legend(["No Churn", "Churn"], loc="upper right")
Mth.set_ylabel('Density')
Mth.set_xlabel('MonthlyCharges')
Mth.set_title('MonthlyCharges by Churn')
# Out:
# Text(0.5, 1.0, 'MonthlyCharges by Churn')

# %% [markdown]
# Insight: Churn is high when MonthlyCharges are high.

# %%
Tot = sns.kdeplot(new_df.TotalCharges[(new_df["Churn"] == 0)],
                  color='Red', fill = True)
Tot = sns.kdeplot(new_df.TotalCharges[(new_df["Churn"] == 1)],
                ax = Tot, color= 'Blue', fill = True )
Tot.legend(["No Churn", "Churn"], loc="upper right")
Tot.set_ylabel('Density')
Tot.set_xlabel('TotalCharges')
Tot.set_title('TotalCharges by Churn')
# Out:
# Text(0.5, 1.0, 'TotalCharges by Churn')

# %% [markdown]
# Insight: At lower TotalCharges, People are more like to Churn.
#
#
#
# *   So, Higher MonthlyCharges, lower Tenure and lower TotalCharges are most likely to churn.

# %%
plt.figure(figsize=(20,8))
new_df_dummies.corr()['Churn'].sort_values(ascending = False)
# Out:
# Churn                                      1.000000
# Contract_Month-to-month                    0.404565
# OnlineSecurity_No                          0.342235
# TechSupport_No                             0.336877
# tenure_group_1 - 12                        0.319628
# InternetService_Fiber optic                0.307463
# PaymentMethod_Electronic check             0.301455
# OnlineBackup_No                            0.267595
# DeviceProtection_No                        0.252056
# MonthlyCharges                             0.192858
# PaperlessBilling_Yes                       0.191454
# Dependents_No                              0.163128
# SeniorCitizen                              0.150541
# Partner_No                                 0.149982
# StreamingMovies_No                         0.130920
# StreamingTV_No                             0.128435
# StreamingTV_Yes                            0.063254
# StreamingMovies_Yes                        0.060860
# ...

# %%
#plt.figure(figsize=(20,8))
new_df_dummies.corr()['Churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %%
#plt.figure(figsize=(10,5))
new_df.corr()['Churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <ipython-input-84-89013532b1cd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_df.corr()['Churn'].sort_values(ascending = False).plot(kind='bar')
# <Axes: >

# %% [markdown]
# **HIGH** Churn seen in month to month contracts, No online security, No Tech support and Fibrt Optics Internet.
#
# **LOW** Churn seen in Long term contracts and No internet services.
#
# Factors like Gender, multiple line and availability of maultiple lines have no impact of Churn.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(new_df_dummies.corr(), cmap='Paired')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,12))
sns.heatmap(new_df_dummies.corr(), cmap='Paired', annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
sns.heatmap(new_df_dummies.corr(), cmap='crest')
# Out:
# <Axes: >

# %% [markdown]
# ## Bivariate Analysis

# %%
new_df1_target0=new_df.loc[new_df["Churn"] ==0] # Active Customers
new_df1_target1=new_df.loc[new_df["Churn"] ==1] # Churned Customers

# %%
len(new_df1_target0)
# Out:
# 5163

# %%
len(new_df1_target1)
# Out:
# 1869

# %%
def uniplot(df, col, title, hue=None):
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 10
    plt.rcParams['axes.titlesize'] = 11
    plt.rcParams['axes.titlepad'] = 15

    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 2*len(df[hue].unique()) if hue else len(df[col].unique())
    fig.set_size_inches(width, 4)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data=df, x=col, order=df[col].value_counts().index, hue=hue, palette='bright')

    plt.show()

# %%
uniplot(new_df1_target1, col='Partner', title= 'Distribution of Gender for Churned Customers', hue='gender')

# %%
uniplot(new_df1_target0, col='Partner', title= 'Distribution of Gender for Churned Customers', hue='gender')

# %%
uniplot(new_df1_target1, col='PaymentMethod', title= 'Distribution of PaymentMethod for Churned Customers', hue='gender')

# %%
uniplot(new_df1_target1, col='PaymentMethod', title= 'Distribution of PaymentMethod for Churned Customers', hue='Partner')

# %%
uniplot(new_df1_target1, col='Partner', title= 'Distribution of PaymentMethod for Churned Customers', hue='Dependents')

# %% [markdown]
# # CONCLUSION
#
#
# *   Senior Citizens are more likely to churn around 42%.
# *   People who have monthly contracts are most likely to churn.
# *   People who have Fiberoptic services are highly churn.
# *   Electronic check payment medium are highest churners.
# *   People who have 2 year contract are less like to churn.
# *   Males who don't have partners are more like to churn, around 33%
# *   Females who use credit card for payment are more churners as compare to Males.
# *   No online security, no tech support people are highly churners.
# *   People with no partners are most likely to churn areound 35%.
